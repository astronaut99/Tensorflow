# %% [markdown]
# # Transfer Learning
#
# * Can Leverage an existing Neural Network architecture which has already learned patterns on similar data to our own
#
# * Tune it according to your own problem

# %% [markdown]
# ## Part 1: Feature Extraction

# %% [markdown]
# #### Becoming One with Data

# %%
# How many images in each folder?
import os

# Walk through 10% data directory & list no. of files
for dirpath,dirnames,filenames in os.walk('10_food_classes_10_percent'):
    print(f"There are {len(dirnames)} directories, {len(filenames)} images in {dirpath}")
# Out:
# There are 2 directories, 0 images in 10_food_classes_10_percent
# There are 10 directories, 0 images in 10_food_classes_10_percent\test
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\chicken_curry
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\chicken_wings
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\fried_rice
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\grilled_salmon
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\hamburger
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\ice_cream
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\pizza
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\ramen
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\steak
# There are 0 directories, 250 images in 10_food_classes_10_percent\test\sushi
# ...

# %% [markdown]
# ***
# #### Creating Data Loaders
#
# We'll use `ImageDataGenerator` to load in our images in batches.
# ***

# %%
# Setup data inputs
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMAGE_SHAPE = (224,224)
BATCH_SIZE = 32

train_dir = "10_food_classes_10_percent/train/"
test_dir = "10_food_classes_10_percent/test/"

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

print("Trainig images:")
train_data_10_percent = train_datagen.flow_from_directory(train_dir,
                                                          target_size=IMAGE_SHAPE,
                                                         batch_size=BATCH_SIZE,
                                                         class_mode="categorical")

print("Testing Images:")
test_data = test_datagen.flow_from_directory(test_dir,
                                            target_size=IMAGE_SHAPE,
                                            batch_size=BATCH_SIZE,
                                            class_mode="categorical")
# Out:
# Trainig images:
# ERROR! Session/line number was not unique in database. History logging moved to new session 42
# Found 750 images belonging to 10 classes.
# Testing Images:
# Found 2500 images belonging to 10 classes.

# %% [markdown]
# #### Setting up Callbacks
#
# Things to run whilst our model trains
# Extra functionality you can add to your model to be performed during or after training. Popular callbacks:
#
# * Tracking experiments with TensorBoard callback
# * Model Checkpoints with ModelCheckpoint callback
# * Stopping a model from training too long with EarlyStopping callback

# %%
## Create TensorBoard Callback
import datetime

def create_tensorboard_callback(dir_name, experiment_name):
    log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d")
    tensorboard_callback = tf.keras.callbacks.Tensorboard(log_dir=log_dir)
    print(f"Saving log files to: {log_dir}")
    return tensorboard_callback

# %% [markdown]
# #### Creating Models using TensorFlow Hub
#
# Pre-trained model at : https://tfhub.dev/

# %%
import tensorflow_hub as hub
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Softwares\Installed\Anaconda\envs\deepl\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-5c017171c13e>", line 1, in <module>
#     import tensorflow_hub as hub
# ModuleNotFoundError: No module named 'tensorflow_hub'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Softwares\Installed\Anaconda\envs\deepl\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# ...
